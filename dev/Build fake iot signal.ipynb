# %% [markdown]
# # Build fake iot signal

# %% [markdown]
# # Import modules

# %%
import os
import sys
import time

import numpy as np
import scipy as sp
from scipy import stats

import matplotlib.pyplot as plt

# %%
print('python version: {}'.format(sys.version))
print('numpy version: {}'.format(np.__version__))
print('scipy version: {}'.format(sp.__version__))
# Out:
# python version: 3.6.5 |Anaconda, Inc.| (default, Apr 29 2018, 16:14:56)
# [GCC 7.2.0]
# numpy version: 1.14.3
# scipy version: 1.1.0

# %% [markdown]
# # Functions

# %% [markdown]
# # Create signal

# %%
# original signal
xs = np.linspace(0,10,1000)
sig0 = xs**2
sig1 = 0.5*xs**2
sig2 = 0.2*xs**2

signals = [sig0,sig1,sig2]

# add some noise

# %%
# plot the signals

fig = plt.figure(figsize=[10,8])
ax = plt.subplot(111)
# ax.plot(xs,sig0,label='signal 0')
# ax.plot(xs,sig1,label='signal 1')
for i,sig in enumerate(signals):
    ax.plot(xs,sig,label='signal {}'.format(i))
ax.grid()
ax.legend()
